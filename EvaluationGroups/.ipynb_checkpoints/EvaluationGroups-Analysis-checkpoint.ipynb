# %%
# %%html
#
# ​
#
# <script>
#
#   function code_toggle() {
#
#     if (code_shown){
#
#       $('div.input').hide('500');
#
#       $('#toggleButton').val('Show Code')
#
#     } else {
#
#       $('div.input').show('500');
#
#       $('#toggleButton').val('Hide Code')
#
#     }
#
#     code_shown = !code_shown
#
#   }
#
#
#
#   $( document ).ready(function(){
#
#     code_shown=false;
#
#     $('div.input').hide()
#
#   });
#
# </script>
#
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>
# Out:
# ​
#
# <script>
#
#   function code_toggle() {
#
#     if (code_shown){
#
#       $('div.input').hide('500');
#
#       $('#toggleButton').val('Show Code')
#
#     } else {
#
#       $('div.input').show('500');
#
#       $('#toggleButton').val('Hide Code')
#
#     }
#
#     code_shown = !code_shown
#
#   }
#
#
#
#   $( document ).ready(function(){
#
#     code_shown=false;
#
#     $('div.input').hide()
#
#   });
#
# </script>
#
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# <img src="http://www.nserc-crsng.gc.ca/_gui/wmms.gif" alt="Canada logo" align="right">
#
# <br>
#
# <img src="http://www.triumf.ca/sites/default/files/styles/gallery_large/public/images/nserc_crsng.gif?itok=H7AhTN_F" alt="NSERC logo" align="right" width = 90>
#
#
#
# # Explore historical funding over the NSERC [Evaluation Groups](http://www.nserc-crsng.gc.ca/NSERC-CRSNG/committees-comites/programs-programmes_eng.asp).
#
#
# Canada's [Open Government Portal](http://open.canada.ca/en) includes [NSERC Awards Data](http://open.canada.ca/data/en/dataset/c1b0f627-8c29-427c-ab73-33968ad9176e) from 1995 through 2016.
#
# The awards data (in .csv format) were copied to an [Amazon Web Services S3 bucket](http://docs.aws.amazon.com/AmazonS3/latest/dev/UsingBucket.html).
#
# > **Acknowledgement:** This notebook was constructed using JupyterHub service from [syzygy.ca](http://syzygy.ca) with assistance from [Ian Allison](https://github.com/ianabc) and India Heisz. -- [James Colliander](http://colliand.com)
#
# ![](https://wwejubwfy.s3.amazonaws.com/NSERC_-_Selection_Committees_and_Evaluation_Groups_2018-04-12_14-37-32.png)

# %%
## Load some tools
import matplotlib.ticker as mtick
# import plotly.graph_objs as go
# import plotly.offline as py
# from plotly.offline import init_notebook_mode, iplot
#  import plotly.tools as tls
import matplotlib.pylab as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas

# %% [markdown]
# ## Load the data from AWS S3 into Jupyter

# %%
## Thanks Ian Allison.
## Install some python libraries
import numpy as np
import pandas as pd
import sys

## Build a data frame with NSERC Awards Data by iteratively reading CSV files hosted on AWS S3.
## It would improve reproducibility if we imported from a definitive NSERC Awards Data.
df = pd.DataFrame()

startYear = 1995
endYear   = 2017  # The last year is not included, so 2017 means we include the 2016 collection but not 2017.

## some columns dropped here for convenience
for year in range(startYear, endYear):
    file = 'https://s3.ca-central-1.amazonaws.com/open-data-ro/NSERC/NSERC_GRT_FYR' + str(year) + '_AWARD.csv.gz'
    df = df.append(pd.read_csv(file, 
                               compression='gzip', 
                               usecols = [1, 2, 3, 4, 5, 7, 9, 11, 12, 13, 17, 28], 
                               encoding='latin-1'
                              )
                  )  
    print(year)
 

## Rename columns for better readability.
df.columns = ['Name', 'Department', 'OrganizationID',
                 'Institution', 'ProvinceEN', 'CountryEN',
                 'FiscalYear', 'AwardAmount', 'ProgramID',
                 'ProgramNameEN', 'Committee', 'ResearchSubjectEN']

## Strip out any leading or trailing whitespace in the ProgramID column
df['ProgramID'] = df['ProgramID'].str.strip();
# Out:
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %% [markdown]
# ## Restrict to EG Committees

# %%
EvaluationGroups = df.loc[(df['Committee']==1501) 
                                   | (df['Committee']==1502)
                                   | (df['Committee']==1503)
                                   | (df['Committee']==1504) 
                                   | (df['Committee']==1505)
                                   | (df['Committee']==1506)
                                   | (df['Committee']==1507)
                                   | (df['Committee']==1508)
                                   | (df['Committee']==1509)
                                   | (df['Committee']==1510)
                                   | (df['Committee']==1511)
                                   | (df['Committee']==1512)]

# %% [markdown]
# ### 2009 is weird

# %%
## 2009 is an outlier so drop it. 2010 is also a bit weird.
EG = EvaluationGroups.loc[~(EvaluationGroups['FiscalYear']==2009)]

# %%
EG['FiscalYear'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %% [markdown]
# ## Total Investment vs. Fiscal Year separated by EG Committee

# %%
## Total investment dollars vs Fiscal Year separated by Evaluation Group Committee
(EG.groupby(['Committee','FiscalYear']).sum()
 ['AwardAmount'].unstack()).plot(
    kind="bar", stacked=False, cmap="viridis", alpha=0.7, figsize=(16, 8), width=1, 
    title="Total dollars invested by Evaluation Group Committee")

# %% [markdown]
# ## Number of Awards vs. Fiscal Year separated by EG Committee

# %%
## Number of Awards vs Fiscal Year separated by Evaluation Group Committee
(EG.groupby(['Committee','FiscalYear']).count()
 ['AwardAmount'].unstack()).plot(
    kind="bar", stacked=False, cmap="viridis", alpha=0.7, figsize=(16, 8), width=1, 
    title="Number of Awards by Evaluation Group Committee")

# %% [markdown]
# ## Average Award Amount vs. Fiscal Year separated by EG Committee

# %%
## Total Dollars invested divided by number of awards vs. Fiscal Year separated by Evaluation Group Committee
((EG.groupby(['Committee','FiscalYear']).sum()
 ['AwardAmount'])/(EvaluationGroups.groupby(['Committee','FiscalYear']).count()
 ['AwardAmount'])).unstack().plot(
    kind="bar", stacked=False, cmap="viridis", alpha=0.7, figsize=(16, 8), width=1, 
    title="Average Award Amount by Evaluation Group Committee")

# %%
## Mean vs Fiscal Year separated by Evaluation Group Committee
(EG.groupby(['Committee','FiscalYear']).mean()
 ['AwardAmount'].unstack()).plot(
    kind="bar", stacked=False, cmap="viridis", alpha=0.7, figsize=(16, 8), width=1, 
    title="Number of Awards by Evaluation Group Committee")

# %%
## Total vs Fiscal Year stacked by Evaluation Group Committee
(EG.groupby(['FiscalYear','Committee']).sum()
 ['AwardAmount'].unstack()).plot(
    kind="bar", stacked=True, cmap="viridis", alpha=0.7, figsize=(16, 8), width=1, 
    title="Total Investment by Evaluation Group Committee across Fiscal Years")

# %%
## Number of Awards vs Fiscal Year stacked by Evaluation Group Committee
(EG.groupby(['FiscalYear','Committee']).count()
 ['AwardAmount'].unstack()).plot(
    kind="bar", stacked=True, cmap="viridis", alpha=0.7, figsize=(16, 8), width=1, 
    title="Number of Awards by Evaluation Group Committee across Fiscal Years")

# %%
EGacrossYears = EG.groupby(['FiscalYear','Committee']).sum()['AwardAmount']

# %%
EGacrossYears.to_csv("eg-years.csv")

# %% [markdown]
# ## Portfolio Changes

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016]

# %%
print("year total")
for year in years:
    print(year, EG.loc[EG['FiscalYear'] == year]['AwardAmount'].sum())
# Out:
# year total
# 2010 94855572
# 2011 151053609
# 2012 212551891
# 2013 267376916
# 2014 334278989
# 2015 315162570
# 2016 328896525

# %%
EGtotalx = {2010:94855572, 2011: 151053609, 2012:212551891, 2013:267376916, 2014:334278989, 2015:315162570,2016:2016}

# %%
EGtotal[2015]
# Out:
# 315162570

# %%
EGt = pd.DataFrame({2010:94855572, 2011: 151053609, 2012:212551891, 
                   2013:267376916, 2014:334278989, 2015:315162570,2016:2016}, index=[0])

# %%
type(EGtotal)
# Out:
# dict

# %%
sales = [('account', ['Jones LLC', 'Alpha Co', 'Blue Inc']),
         ('Jan', [150, 200, 50]),
         ('Feb', [200, 210, 90]),
         ('Mar', [140, 215, 95]),
         ]
df = pd.DataFrame.from_items(sales)

# %%
EGtotal = [('FiscalYear',[2010,2011,2012,2013,2014,2015,2016]),
                   ('EGTotal',[94855572,151053609,212551891,267376916,334278989,315162570,328896525])]

# %%
EGt = pd.DataFrame.from_items(EGtotal)

# %%
EGt.loc[EGt['FiscalYear']==2010]['EGTotal'][0]
# Out:
# 94855572

# %%
## Mean vs Fiscal Year separated by Evaluation Group Committee
(EG.groupby(['Committee','FiscalYear']).sum()
 ['AwardAmount'].unstack()/(EGt.loc[EGt['FiscalYear']]['EGTotal'][0])).plot(
    kind="bar", stacked=False, cmap="viridis", alpha=0.7, figsize=(16, 8), width=1, 
    title="Number of Awards by Evaluation Group Committee")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-a8f584c17870> in <module>()
#       1 ## Mean vs Fiscal Year separated by Evaluation Group Committee
#       2 (EG.groupby(['Committee','FiscalYear']).sum()
# ----> 3  ['AwardAmount'].unstack()/(EGt.loc[EGt['FiscalYear']]['EGTotal'][0])).plot(
#       4     kind="bar", stacked=False, cmap="viridis", alpha=0.7, figsize=(16, 8), width=1,
#       5     title="Number of Awards by Evaluation Group Committee")
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1470                     raise ValueError('Cannot index with multidimensional key')
#    1471
# -> 1472                 return self._getitem_iterable(key, axis=axis)
#    1473
#    1474             # nested tuple slicing
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1034     def _getitem_iterable(self, key, axis=0):
#    1035         if self._should_validate_iterable(axis):
# -> 1036             self._has_valid_type(key, axis)
#    1037
#    1038         labels = self.obj._get_axis(axis)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1393
#    1394                 raise KeyError("None of [%s] are in the [%s]" %
# -> 1395                                (key, self.obj._get_axis_name(axis)))
#    1396
#    1397             return True
#
# KeyError: 'None of [0    2010\n1    2011\n2    2012\n3    2013\n4    2014\n5    2015\n6    2016\nName: FiscalYear, dtype: int64] are in the [index]'

# %% [markdown]
# ### AwardAmount Density vs. Fiscal Year

# %%
## AwardAmount Density vs. Fiscal Year
(EG.groupby(['Committee','FiscalYear']).mean()
 ['AwardAmount'].unstack()).plot(
    kind="density", stacked=False, cmap="viridis", alpha=0.7, figsize=(16, 8), 
    title="Number of Awards by Evaluation Group Committee")

# %%
## Mean vs Fiscal Year separated by Evaluation Group Committee
(EG.groupby(['FiscalYear','Committee']).mean()
 ['AwardAmount'].unstack()).plot(
    kind="density", stacked=False, cmap="viridis", alpha=0.9, figsize=(16, 8), 
    title="AwardAmount Distribution across EG Committees")

# %% [markdown]
# ### Observations
#
# + There is a general trend for the average award size to be flat or shrinking. Inflation adjustment would
# shrink more recent years. Note the frequent drop for 2015 and 2016 across most Committees.
# + Section 1508 is visibly underfunded.
# + Chemistry (1504) dropped significantly in 2015 and 2016.

# %% [markdown]
# ## (work-in-progress) Bin Levels vs. Fiscal Year separated by EG Committee

# %%
committee = 1504
fiscal = 2013
sectionyear = EG.loc[(EG['Committee'] == committee) & (EG['FiscalYear'] == fiscal) ]

# %%
print("Distribution of Award Amounts for Evaluation Group " + str(committee) + " in Fiscal Year " + str(fiscal))
sectionyear['AwardAmount'].plot(kind="hist", bins=100)
# Out:
# Distribution of Award Amounts for Evaluation Group 1504 in Fiscal Year 2013

# %%
sectionyear['AwardAmount'].plot(kind="kde")

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016]

# %%
for year in years:
    sectionyear = EG.loc[(EG['Committee'] == committee) & (EG['FiscalYear'] == year) ]
    print(year)
    sectionyear['AwardAmount'].plot(kind="hist", bins=100, alpha=0.7)
# Out:
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
EG.groupby(['Committee','Committee'])['AwardAmount'].count().unstack().plot.hist(bins=20, subplots=True, 
    figsize=(16, 12),stacked=False, 
    title="some title")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f6374a77e80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f637bd67320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6374a183c8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6374978198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6374917320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6374917358>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63748d5630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63748f87b8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f637489a940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63748baac8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f637485bc50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f637487ddd8>], dtype=object)

# %%
section = 1503
sec = df.loc[df['Committee'] == section]

# %%
sec
# Out:
#                             Name  \
# 482                  Amyot, Marc
# 1476           Beauplet, Gwénaël
# 1719               Bentzen, Paul
# 1803           Bernatchez, Louis
# 2161       BlouinDemers, Gabriel
# 3144               Cahill, James
# 3673              Chapman, Colin
# 4468               Cooke, Steven
# 4734          Cristescu, Melania
# 5887              Drevnick, Paul
# 7111              Fortin, Daniel
# 7247               Fraser, Dylan
# 8841                 Hall, Britt
# 9122               Hart, Michael
# 9309               Heath, Daniel
# 9410              Hendry, Andrew
# 10274              Irwin, Darren
# 13305        Lindgren, BoStaffan
# 13361            Litvak, Matthew
# 13365        Litzgus, Jacqueline
# 13582               Love, Oliver
# 15026            Mennill, Daniel
# 15495       Montevecchi, William
# 15637            Morris, Douglas
# 17431    PierceyNormore, Michele
# 5887                     Evolution and ecology
# 7111                     Evolution and ecology
# 7247                     Evolution and ecology
# 8841                          Chemical ecology
# 9122                     Evolution and ecology
# 9309                     Evolution and ecology
# 9410                     Evolution and ecology
# 10274                    Evolution and ecology
# 13305                 Plant-animal interaction
# 13361            Aquatic ecology and limnology
# 13365                    Evolution and ecology
# 13582                                Behaviour
# 15026                    Evolution and ecology
# 15495                                Behaviour
# 15637                      Evolutionary theory
# 17431                          Gene expression
# 17493                    Evolution and ecology
# 17710                    Evolution and ecology
# 19418            Aquatic ecology and limnology
# 19551                      Animal reproduction
# 20361                    Evolution and ecology
# ...                                        ...
# 23493                                Behaviour
# 23503                    Evolution and ecology
# 23564                             Protozoology
# 23593       Biogeography and landscape ecology
# 23594                      Evolutionary theory
# 23609                    Evolution and ecology
# 23700  Taxonomy, systematics and phylogenetics
# 23733     Sociobiology and behavioural ecology
# 23743                      Evolutionary theory
# 23755                             Microbiology
# 23773                                Behaviour
# 23785       Biogeography and landscape ecology
# 23802                      Evolutionary theory
# 23845                    Evolution and ecology
# 23851                    Evolution and ecology
# 23880                           Animal ecology
# 23902                                Behaviour
# 23936                            Plant ecology
# 23948            Aquatic ecology and limnology
# 23985            Aquatic ecology and limnology
# 23993                    Evolution and ecology
# 24021                    Evolution and ecology
# 24142       Biogeography and landscape ecology
# 24146                 Plant-animal interaction
# 24173                    Evolution and ecology
# 24175            Aquatic ecology and limnology
# 24267            Aquatic ecology and limnology
# 24391            Aquatic ecology and limnology
# 24494     Sociobiology and behavioural ecology
# 24735                           Animal ecology
#
# [3057 rows x 12 columns]

# %%
## Mean vs Fiscal Year separated by Evaluation Group Committee
(sec.groupby(['Institution','FiscalYear']).mean()
 ['AwardAmount'].unstack()).plot(
    kind="density", stacked=False, cmap="viridis", alpha=0.9, figsize=(16, 8), 
    title="AwardAmount Distribution across EG Committees")

# %%
## 2009 is weird
sec = sec.loc[~(sec['FiscalYear']==2009)]

# %%
## Mean vs Fiscal Year separated by Evaluation Group Committee
(sec.groupby(['ProvinceEN','FiscalYear']).mean()
 ['AwardAmount'].unstack()).plot(
    kind="density", stacked=True, subplots=True, cmap="viridis", alpha=0.9, figsize=(16, 12), 
    title="AwardAmount Distribution within committee across Fiscal Years")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f637c217c18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f637c1cf748>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f637c1ee8d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f637c18ba58>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f637c1adbe0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f637c1adc18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f637c16eef0>], dtype=object)

# %%
sec.groupby(['FiscalYear'])['AwardAmount'].plot()
# Out:
# FiscalYear
# 2009    AxesSubplot(0.125,0.125;0.775x0.755)
# 2010    AxesSubplot(0.125,0.125;0.775x0.755)
# 2011    AxesSubplot(0.125,0.125;0.775x0.755)
# 2012    AxesSubplot(0.125,0.125;0.775x0.755)
# 2013    AxesSubplot(0.125,0.125;0.775x0.755)
# 2014    AxesSubplot(0.125,0.125;0.775x0.755)
# 2015    AxesSubplot(0.125,0.125;0.775x0.755)
# 2016    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: AwardAmount, dtype: object
