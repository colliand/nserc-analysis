# %% [markdown]
# <img src="http://www.nserc-crsng.gc.ca/_gui/wmms.gif" alt="Canada logo" align="right">
#
# <br>
#
# <img src="http://www.triumf.ca/sites/default/files/styles/gallery_large/public/images/nserc_crsng.gif?itok=H7AhTN_F" alt="NSERC logo" align="right" width = 90>
#
#
#
# # Exploring NSERC Awards Data
#
#
# Canada's [Open Government Portal](http://open.canada.ca/en) includes [NSERC Awards Data](http://open.canada.ca/data/en/dataset/c1b0f627-8c29-427c-ab73-33968ad9176e) from 1995 through 2016.
#
# The awards data (in .csv format) were copied to an [Amazon Web Services S3 bucket](http://docs.aws.amazon.com/AmazonS3/latest/dev/UsingBucket.html). <br>
#
# This open Jupyter notebook shows all of the "orphaned" researchers who are funded by the 1508 Mathematics and Statistics committee in 2016 but are not part of the mathematics department.
#
# > **Acknowledgement:** I thank [Ian Allison](https://github.com/ianabc) and [James Colliander](http://colliand.com) of the [Pacific Institute for the Mathematical Sciences](http://www.pims.math.ca/) for building the [JupyterHub service](http://syzygy.ca) and for help with this notebook. -- I. Heisz

# %%
import numpy as np
import pandas as pd
import sys

df = pd.DataFrame()

startYear = 2014
endYear   = 2019  # The last year is not included, so if it was 2017 it means we include the 2016 collection but not 2017.

for year in range(startYear, endYear):
    file = 'https://s3.ca-central-1.amazonaws.com/open-data-ro/NSERC/NSERC_GRT_FYR' + str(year) + '_AWARD.csv.gz'
    df = df.append(pd.read_csv(file, 
                               compression='gzip', 
                               usecols = [1, 2, 3, 4, 5, 7, 11, 12, 13, 17, 28], 
                               encoding='latin-1'
                              )
                  )  
    print(year)
 
## Rename columns for better readability.
df.columns = ['Name', 'Department', 'OrganizationID',
                 'Institution', 'ProvinceEN', 'CountryEN',
                 'AwardAmount', 'ProgramID',
                 'ProgramNameEN', 'Committee', 'ResearchSubjectEN']

## Strip out any leading or trailing whitespace in the ProgramID column
df['ProgramID'] = df['ProgramID'].str.strip();
# Out:
# 2014
# 2015
# 2016
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-1-11dbbb3bded3> in <module>
#      13                                compression='gzip',
#      14                                usecols = [1, 2, 3, 4, 5, 7, 11, 12, 13, 17, 28],
# ---> 15                                encoding='latin-1'
#      16                               )
#      17                   )
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     411     compression = _infer_compression(filepath_or_buffer, compression)
#     412     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 413         filepath_or_buffer, encoding, compression)
#     414     kwds['compression'] = compression
#     415
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     200
#     201     if _is_url(filepath_or_buffer):
# --> 202         req = _urlopen(filepath_or_buffer)
#     203         content_encoding = req.headers.get('Content-Encoding', None)
#     204         if content_encoding == 'gzip':
#
# ~/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
selectedData = df
selectedData = selectedData.loc[(selectedData['Committee'] == 1508)]

# %%
# remove people in the math department
subject = 'Math'
selectedData = selectedData[selectedData['Department'].str.contains(subject)==False]

# remove people in the statistics department
subject = 'Stat'
selectedData = selectedData[selectedData['Department'].str.contains(subject)==False]

# %%
selectedData = selectedData.drop('Committee', axis=1)
selectedData
# Out:
#                         Name  \
# 47             Ramsay, James
# 698      Whittington, Stuart
# 742           Heunis, Andrew
# 882            Rolfsen, Dale
# 902           Jackson, David
# 950            Donner, Allan
# 951        Dufour, JeanMarie
# 970          Delfour, Michel
# 972          Walter, Stephen
# 996             Goulden, Ian
# 1024        Wolkowicz, Henry
# 1074    Rousseau, Christiane
# 1079     Godsil, Christopher
# 1158            Knight, John
# 1243          Forsyth, Peter
# 1427        Remillard, Bruno
# 1715           Wagner, David
# 1758    Abrahamowicz, Michal
# 2026            Hoang, Chinh
# 2233       Dutilleul, Pierre
# 2264        Haxell, Penelope
# 2976        Marceau, Etienne
# 2977        Cossette, Hélène
# 2993           Tu, Dongsheng
# 3146           Geelen, James
# 3156           Platt, Robert
# 3384          Kershaw, JohnA
# 3436    Buono, PietroLuciano
# 3548         Pizzi, Nicolino
# 3588           Peng, Yingwei
# ...                      ...
# 18236  Pullenayegum, Eleanor
# 18248         Purbhoo, Kevin
# 18726       Rémillard, Bruno
# 18866         Richter, Bruce
# 19131          Rolfsen, Dale
# 19226       Rosychuk, Rhonda
# 19465          Saarela, Olli
# 19560       SaintAubin, Yvan
# 19786      Savalei, Victoria
# 19934    Schnitzer, Mireille
# 21236      Stengos, Thanasis
# 21238         Stentoft, Lars
# 21278        Stewart, Connie
# 21442            Strug, Lisa
# 21761          Talbot, Denis
# 21946           Tcaciuc, Adi
# 22287        Torabi, Mahmoud
# 22530          Tu, Dongsheng
# 22881      vanVeen, Lennaert
# 23187          Wagner, David
# 23257        Walter, Stephen
# 23343              Wang, Lin
# 23747    Whittington, Stuart
# 24014       Wolkowicz, Henry
# 24090    Wong, WilliamWaiLun
# 24128      Woolford, Douglas
# 24539            Yi, Yanqing
# 24975              Zhou, Rui
# 24997           Zhu, Hongmei
# 25082         Zou, Guangyong
#
#                                               Department  OrganizationID  \
# 47                                            Psychology              61
# 698                        Chemistry (St. George Campus)              31
# 742                    Electrical & Computer Engineering              33
# 882                                  Science, Faculty of               2
# 902                       Combinatorics and Optimization              33
# 950                       Epidemiology and Biostatistics              36
# 951                                            Economics              61
# 970                  Recherches mathématiques, Centre de              63
# 972              Clinical Epidemiology and Biostatistics              27
# 996                       Combinatorics and Optimization              33
# 1024                      Combinatorics and Optimization              33
# 1074                   Arts et des sciences, faculté des              63
# 1079                      Combinatorics and Optimization              33
# 1158                                           Economics              36
# 1243       Computer Science, David R. Cheriton School of              33
# 1427   Méthodes quantitatives de gestion, Service de ...              65
# 1715                      Combinatorics and Optimization              33
# 1758   Epidemiology, Biostatistics and Occupational H...              61
# 2026                        Physics and Computer Science              35
# 2233                                       Plant Science              61
# 2264                      Combinatorics and Optimization              33
# 2976                                 Actuariat, École d'              51
# 2977                                 Actuariat, École d'              51
# 2993                   Community Health and Epidemiology              29
# 3146                      Combinatorics and Optimization              33
# 3156                                          Pediatrics              61
# 3384   Forestry and Environmental Management, Faculty of              75
# 3436                                 Science, Faculty of           19222
# 3548                                    Computer Science              19
# 3588                   Community Health and Epidemiology              29
# ...                                                  ...             ...
# 18236                 Dalla Lana School of Public Health              31
# 18248                     Combinatorics and Optimization              33
# 18726  Recherche, Direction de la - Recherche, Direct...              65
# 18866                     Combinatorics and Optimization              33
# 19131                                Science, Faculty of               2
# 19226                            Pediatrics - Pediatrics               9
# 996    Discovery Grants Program - Individual
# 1024   Discovery Grants Program - Individual
# 1074   Discovery Grants Program - Individual
# 1079   Discovery Grants Program - Individual
# 1158   Discovery Grants Program - Individual
# 1243   Discovery Grants Program - Individual
# 1427   Discovery Grants Program - Individual
# 1715   Discovery Grants Program - Individual
# 1758   Discovery Grants Program - Individual
# 2026   Discovery Grants Program - Individual
# 2233   Discovery Grants Program - Individual
# 2264   Discovery Grants Program - Individual
# 2976   Discovery Grants Program - Individual
# 2977   Discovery Grants Program - Individual
# 2993   Discovery Grants Program - Individual
# 3146   Discovery Grants Program - Individual
# 3156   Discovery Grants Program - Individual
# 3384   Discovery Grants Program - Individual
# 3436   Discovery Grants Program - Individual
# 3548   Discovery Grants Program - Individual
# 3588   Discovery Grants Program - Individual
# ...                                      ...
# 18236  Discovery Grants Program - Individual
# 18248  Discovery Grants Program - Individual
# 18726  Discovery Grants Program - Individual
# 18866  Discovery Grants Program - Individual
# 19131  Discovery Grants Program - Individual
# 19226  Discovery Grants Program - Individual
# 19465  Discovery Grants Program - Individual
# 19560  Discovery Grants Program - Individual
# 19786  Discovery Grants Program - Individual
# 19934  Discovery Grants Program - Individual
# 21236  Discovery Grants Program - Individual
# 21238  Discovery Grants Program - Individual
# 21278  Discovery Grants Program - Individual
# 21442  Discovery Grants Program - Individual
# 21761  Discovery Grants Program - Individual
# 21946  Discovery Grants Program - Individual
# 22287  Discovery Grants Program - Individual
# 22530  Discovery Grants Program - Individual
# 22881  Discovery Grants Program - Individual
# 23187  Discovery Grants Program - Individual
# 23257  Discovery Grants Program - Individual
# 23343  Discovery Grants Program - Individual
# 23747  Discovery Grants Program - Individual
# 24014  Discovery Grants Program - Individual
# 24090  Discovery Grants Program - Individual
# 24128  Discovery Grants Program - Individual
# 24539  Discovery Grants Program - Individual
# 24975  Discovery Grants Program - Individual
# 24997  Discovery Grants Program - Individual
# 25082  Discovery Grants Program - Individual
#
#                               ResearchSubjectEN
# 47                   Statistics and probability
# 698    Statistical mechanics and thermodynamics
# 742                         Applied probability
# 882                                     Algebra
# 902                               Combinatorics
# 950                               Biostatistics
# 951                  Statistics and probability
# 970     Optimisation and optimal control theory
# 972                               Biostatistics
# 996                               Combinatorics
# 1024    Optimisation and optimal control theory
# 1074             Non-linear and global analysis
# 1079                              Combinatorics
# 1158                       Stochastic processes
# 1243                   Mathematics of computing
# 1427                       Stochastic processes
# 1715                              Combinatorics
# 1758                 Statistics and probability
# 2026                              Combinatorics
# 2233                 Statistics and probability
# 2264                              Combinatorics
# 2976                 Statistics and probability
# 2977                 Statistics and probability
# 2993                         Statistical theory
# 3146                              Combinatorics
# 3156                              Biostatistics
# 3384                              Biostatistics
# 3436              Linear and non-linear systems
# 3548                     Mathematical modelling
# 3588                              Biostatistics
# ...                                         ...
# 18236                             Biostatistics
# 18248                             Combinatorics
# 18726                      Stochastic processes
# 18866                             Combinatorics
# 19131                                   Algebra
# 19226                        Statistical theory
# 19465                             Biostatistics
# 19560  Statistical mechanics and thermodynamics
# 19786                        Applied statistics
# 19934                             Biostatistics
# 21236                      Time series analysis
# 21238                    Mathematical modelling
# 21278                        Applied statistics
# 21442                             Biostatistics
# 21761                             Biostatistics
# 21946   Functional analysis and operator theory
# 22287                        Applied statistics
# 22530                             Biostatistics
# 22881        Mathematical biology andphysiology
# 23187                             Combinatorics
# 23257                             Biostatistics
# 23343        Mathematical biology andphysiology
# 23747  Statistical mechanics and thermodynamics
# 24014   Optimisation and optimal control theory
# 24090                        Applied statistics
# 24128                        Applied statistics
# 24539                             Biostatistics
# 24975                        Applied statistics
# 24997                        Numerical analysis
# 25082                             Biostatistics
#
# [360 rows x 10 columns]

# %% [markdown]
# ## Institution Orphans

# %%
pims_sites = ['SFU', 'UA', 'UBC', 'UC', 'UL', 'UM', 'UR', 'US', 'UV']

# %%
org_id = {'SFU': 5,
          'UA': 9,
          'UBC': 2,
          'UC': 11,
          'UL': 12,
          'UM': 19,
          'UR': 17,
          'US': 16,
          'UV': 7}

# %%
## Localize to single institution (e.g. UA)
df = selectedData.loc[(selectedData['OrganizationID'] == org_id['UC'])]
df.drop(['ProvinceEN', 'CountryEN', 'OrganizationID', 'Institution'], axis = 1)
# Out:
#                Name                                         Department  \
# 5129   Deardon, Rob  Veterinary Medicine, Faculty of - Veterinary M...
# 12942  Li, Haocheng                                Oncology - Oncology
# 5205   Deardon, Rob  Veterinary Medicine, Faculty of - Veterinary M...
# 13184  Li, Haocheng                                Oncology - Oncology
#
#        AwardAmount ProgramID                          ProgramNameEN  \
# 5129         25000     RGPIN  Discovery Grants Program - Individual
# 12942        13000     RGPIN  Discovery Grants Program - Individual
# 5205         25000     RGPIN  Discovery Grants Program - Individual
# 13184        13000     RGPIN  Discovery Grants Program - Individual
#
#              ResearchSubjectEN
# 5129             Biostatistics
# 12942  Nonparametric inference
# 5205             Biostatistics
# 13184  Nonparametric inference

# %%
## List the records of orphans for each PIMS site
for inst in pims_sites:
    orph_inst = selectedData.loc[(selectedData['OrganizationID'] == org_id[inst])]
    orph_inst.drop(['ProvinceEN', 'CountryEN', 'OrganizationID', 'Institution'], axis = 1)
    display(orph_inst)
# Out:
#                        Name  \
# 7571        Gencay, Ramazan
# 7614        Gencay, Ramazan
# 14531  McCandless, Lawrence
# 7778        Gencay, Ramazan
# 14786  McCandless, Lawrence
#
#                                               Department  OrganizationID  \
# 7571                                           Economics               5
# 7614                                           Economics               5
# 14531  Health Sciences, Faculty of - Health Sciences,...               5
# 7778                                           Economics               5
# 14786  Health Sciences, Faculty of - Health Sciences,...               5
#
#                    Institution        ProvinceEN CountryEN  AwardAmount  \
# 7571   Simon Fraser University  British Columbia    CANADA        14000
# 7614   Simon Fraser University  British Columbia    CANADA        14000
# 14531  Simon Fraser University  British Columbia    CANADA        17000
# 7778   Simon Fraser University  British Columbia    CANADA        14000
# 14786  Simon Fraser University  British Columbia    CANADA        17000
#
#       ProgramID                          ProgramNameEN  \
# 7571      RGPIN  Discovery Grants Program - Individual
# 7614      RGPIN  Discovery Grants Program - Individual
# 14531     RGPIN  Discovery Grants Program - Individual
# 7778      RGPIN  Discovery Grants Program - Individual
# 14786     RGPIN  Discovery Grants Program - Individual
#
#              ResearchSubjectEN
# 7571   Nonparametric inference
# 7614   Nonparametric inference
# 14531            Biostatistics
# 7778   Nonparametric inference
# 14786            Biostatistics
#                       Name                                       Department  \
# 3731      Rosychuk, Rhonda                                       Pediatrics
# 4765       Safouhi, Hassan                                Campus Saint-Jean
# 5615           Heo, Giseon                                        Dentistry
# 7253          Tcaciuc, Adi                        Arts and Science Division
# 9248           Heo, Giseon                                        Dentistry
# 18587     Rosychuk, Rhonda                                       Pediatrics
# 18875      Safouhi, Hassan                                Campus Saint-Jean
# 1611   Belhamadia, Youssef  Biomedical Engineering - Biomedical Engineering
# 9317           Heo, Giseon                                        Dentistry
# 18781     Rosychuk, Rhonda                                       Pediatrics
# 19053      Safouhi, Hassan                                Campus Saint-Jean
# 9507           Heo, Giseon                            Dentistry - Dentistry
# 19226     Rosychuk, Rhonda                          Pediatrics - Pediatrics
#
#        OrganizationID            Institution ProvinceEN CountryEN  \
# 3731                9  University of Alberta    Alberta    CANADA
# 4765                9  University of Alberta    Alberta    CANADA
# 5615                9  University of Alberta    Alberta    CANADA
# 7253                9  University of Alberta    Alberta    CANADA
# 9248                9  University of Alberta    Alberta    CANADA
# 18587               9  University of Alberta    Alberta    CANADA
# 18875               9  University of Alberta    Alberta    CANADA
# 1611                9  University of Alberta    Alberta    CANADA
# 9317                9  University of Alberta    Alberta    CANADA
# 18781               9  University of Alberta    Alberta    CANADA
# 19053               9  University of Alberta    Alberta    CANADA
# 9507                9  University of Alberta    Alberta    CANADA
# 19226               9  University of Alberta    Alberta    CANADA
#
#        AwardAmount ProgramID                          ProgramNameEN  \
# 3731         12000     RGPIN  Discovery Grants Program - Individual
# 4765         15000     RGPIN  Discovery Grants Program - Individual
# 5615         12000     RGPIN  Discovery Grants Program - Individual
# 7253          5838     RGPIN  Discovery Grants Program - Individual
# 9248         12000     RGPIN  Discovery Grants Program - Individual
# 18587        12000     RGPIN  Discovery Grants Program - Individual
# 18875        15000     RGPIN  Discovery Grants Program - Individual
# 1611         11000     RGPIN  Discovery Grants Program - Individual
# 9317         12000     RGPIN  Discovery Grants Program - Individual
# 18781        12000     RGPIN  Discovery Grants Program - Individual
# 19053        15000     RGPIN  Discovery Grants Program - Individual
# 9507         18000     RGPIN  Discovery Grants Program - Individual
# 19226        33000     RGPIN  Discovery Grants Program - Individual
#
#                              ResearchSubjectEN
# 3731                Statistics and probability
# 4765                        Numerical analysis
# 5615                        Applied statistics
# 7253   Functional analysis and operator theory
# 9248                        Applied statistics
# 18587               Statistics and probability
# 18875                       Numerical analysis
# 1611        Mathematical biology andphysiology
# 9317                        Applied statistics
# 18781               Statistics and probability
# 19053                       Numerical analysis
# 9507                        Applied statistics
# 19226                       Statistical theory
#                      Name                                         Department  \
# 882         Rolfsen, Dale                                Science, Faculty of
# 4200         MacNab, Ying            Population and Public Health, School of
# 3703         Chen, Jiahua                                         statistics
# 10737  Kasahara, Hiroyuki                             No Department/Division
# 13605        MacNab, Ying            Population and Public Health, School of
# 18491       Rolfsen, Dale                                Science, Faculty of
# 14039               Biostatistics
# 19131                     Algebra
# 19786          Applied statistics
#                Name                                         Department  \
# 5129   Deardon, Rob  Veterinary Medicine, Faculty of - Veterinary M...
# 12942  Li, Haocheng                                Oncology - Oncology
# 5205   Deardon, Rob  Veterinary Medicine, Faculty of - Veterinary M...
# 13184  Li, Haocheng                                Oncology - Oncology
#
#        OrganizationID            Institution ProvinceEN CountryEN  \
# 5129               11  University of Calgary    Alberta    CANADA
# 12942              11  University of Calgary    Alberta    CANADA
# 5205               11  University of Calgary    Alberta    CANADA
# 13184              11  University of Calgary    Alberta    CANADA
#
#        AwardAmount ProgramID                          ProgramNameEN  \
# 5129         25000     RGPIN  Discovery Grants Program - Individual
# 12942        13000     RGPIN  Discovery Grants Program - Individual
# 5205         25000     RGPIN  Discovery Grants Program - Individual
# 13184        13000     RGPIN  Discovery Grants Program - Individual
#
#              ResearchSubjectEN
# 5129             Biostatistics
# 12942  Nonparametric inference
# 5205             Biostatistics
# 13184  Nonparametric inference
# Empty DataFrame
# Columns: [Name, Department, OrganizationID, Institution, ProvinceEN, CountryEN, AwardAmount, ProgramID, ProgramNameEN, ResearchSubjectEN]
# Index: []
#                   Name                                         Department  \
# 3548   Pizzi, Nicolino                                   Computer Science
# 8735      Hao, Xuemiao   Warren Centre for Actuarial Studies and Research
# 9381    Frank, Julieta              Agribusiness & Agricultural Economics
# 9392   Torabi, Mahmoud                          Community Health Sciences
# 7098    Frank, Julieta              Agribusiness & Agricultural Economics
# 17276  Pizzi, Nicolino                                   Computer Science
# 21541  Torabi, Mahmoud                          Community Health Sciences
# 17457  Pizzi, Nicolino                                   Computer Science
# 21769  Torabi, Mahmoud                          Community Health Sciences
# 24366        Zhou, Rui  Warren Centre for Actuarial Studies and Resear...
# 7231    Frank, Julieta              Agribusiness & Agricultural Economics
# 9086      Hao, Xuemiao   Warren Centre for Actuarial Studies and Research
# 22287  Torabi, Mahmoud  Community Health Sciences - Community Health S...
# 24975        Zhou, Rui  Warren Centre for Actuarial Studies and Resear...
#
#        OrganizationID             Institution ProvinceEN CountryEN  \
# 3548               19  University of Manitoba   Manitoba    CANADA
# 8735               19  University of Manitoba   Manitoba    CANADA
# 9381               19  University of Manitoba   Manitoba    CANADA
# 9392               19  University of Manitoba   Manitoba    CANADA
# 7098               19  University of Manitoba   Manitoba    CANADA
# 17276              19  University of Manitoba   Manitoba    CANADA
# 21541              19  University of Manitoba   Manitoba    CANADA
# 17457              19  University of Manitoba   Manitoba    CANADA
# 21769              19  University of Manitoba   Manitoba    CANADA
# 24366              19  University of Manitoba   Manitoba    CANADA
# 7231               19  University of Manitoba   Manitoba    CANADA
# 9086               19  University of Manitoba   Manitoba    CANADA
# 22287              19  University of Manitoba   Manitoba    CANADA
# 24975              19  University of Manitoba   Manitoba    CANADA
#
#        AwardAmount ProgramID                          ProgramNameEN  \
# 3548         12000     RGPIN  Discovery Grants Program - Individual
# 8735         16700     RGPIN  Discovery Grants Program - Individual
# 9381         17000     RGPIN  Discovery Grants Program - Individual
# 9392         17000     RGPIN  Discovery Grants Program - Individual
# 7098         17000     RGPIN  Discovery Grants Program - Individual
# 17276        12000     RGPIN  Discovery Grants Program - Individual
# 21541        17000     RGPIN  Discovery Grants Program - Individual
# 17457        12000     RGPIN  Discovery Grants Program - Individual
# 21769        17000     RGPIN  Discovery Grants Program - Individual
# 24366        13000     RGPIN  Discovery Grants Program - Individual
# 7231         17000     RGPIN  Discovery Grants Program - Individual
# 9086         16700     RGPIN  Discovery Grants Program - Individual
# 22287        27000     RGPIN  Discovery Grants Program - Individual
# 24975        13000     RGPIN  Discovery Grants Program - Individual
#
#             ResearchSubjectEN
# 3548   Mathematical modelling
# 8735      Applied probability
# 9381     Time series analysis
# 9392       Survey methodology
# 7098     Time series analysis
# 17276  Mathematical modelling
# 21541      Survey methodology
# 17457  Mathematical modelling
# 21769      Survey methodology
# 24366      Applied statistics
# 7231     Time series analysis
# 9086      Applied probability
# 22287      Applied statistics
# 24975      Applied statistics
# Empty DataFrame
# Columns: [Name, Department, OrganizationID, Institution, ProvinceEN, CountryEN, AwardAmount, ProgramID, ProgramNameEN, ResearchSubjectEN]
# Index: []
#                  Name                Department  OrganizationID  \
# 13228  Feng, CindyXin  Public Health, School of              16
# 6712   Feng, CindyXin  Public Health, School of              16
# 6704   Feng, CindyXin  Public Health, School of              16
# 6810   Feng, CindyXin  Public Health, School of              16
#
#                       Institution    ProvinceEN CountryEN  AwardAmount  \
# 13228  University of Saskatchewan  Saskatchewan    CANADA        15000
# 6712   University of Saskatchewan  Saskatchewan    CANADA        15000
# 6704   University of Saskatchewan  Saskatchewan    CANADA        15000
# 6810   University of Saskatchewan  Saskatchewan    CANADA        15000
#
#       ProgramID                          ProgramNameEN  \
# 13228     RGPIN  Discovery Grants Program - Individual
# 6712      RGPIN  Discovery Grants Program - Individual
# 6704      RGPIN  Discovery Grants Program - Individual
# 6810      RGPIN  Discovery Grants Program - Individual
#
#                 ResearchSubjectEN
# 13228  Statistics and probability
# 6712   Statistics and probability
# 6704   Statistics and probability
# 6810   Statistics and probability
# Empty DataFrame
# Columns: [Name, Department, OrganizationID, Institution, ProvinceEN, CountryEN, AwardAmount, ProgramID, ProgramNameEN, ResearchSubjectEN]
# Index: []

# %%
## List the names of orphans for each PIMS site
for inst in pims_sites:
    orph_inst = selectedData.loc[(selectedData['OrganizationID'] == org_id[inst])]
    orph_inst.drop(['ProvinceEN', 'CountryEN', 'OrganizationID', 'Institution'], axis = 1)
    print(inst,orph_inst['Name'].unique())
# Out:
# SFU ['Gencay, Ramazan' 'McCandless, Lawrence']
# UA ['Rosychuk, Rhonda' 'Safouhi, Hassan' 'Heo, Giseon' 'Tcaciuc, Adi'
#  'Belhamadia, Youssef']
# UBC ['Rolfsen, Dale' 'MacNab, Ying' 'Chen, Jiahua' 'Kasahara, Hiroyuki'
#  'Fisher, Adlai' 'Loeppky, Jason' 'Savalei, Victoria']
# UC ['Deardon, Rob' 'Li, Haocheng']
# UL []
# UM ['Pizzi, Nicolino' 'Hao, Xuemiao' 'Frank, Julieta' 'Torabi, Mahmoud'
#  'Zhou, Rui']
# UR []
# US ['Feng, CindyXin']
# UV []
