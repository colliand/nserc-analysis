# %% [markdown]
# <img src="http://www.nserc-crsng.gc.ca/_gui/wmms.gif" alt="Canada logo" align="right">
#
# <br>
#
# <img src="http://www.triumf.ca/sites/default/files/styles/gallery_large/public/images/nserc_crsng.gif?itok=H7AhTN_F" alt="NSERC logo" align="right" width = 90>
#
#
#
# # Exploring NSERC Awards Data
#
#
# Canada's [Open Government Portal](http://open.canada.ca/en) includes [NSERC Awards Data](http://open.canada.ca/data/en/dataset/c1b0f627-8c29-427c-ab73-33968ad9176e) from 1995 through 2016.
#
# The awards data (in .csv format) were copied to an [Amazon Web Services S3 bucket](http://docs.aws.amazon.com/AmazonS3/latest/dev/UsingBucket.html). <br>
#
# This open Jupyter notebook shows all of the "orphaned" researchers who are funded by the 1508 Mathematics and Statistics committee in 2016 but are not part of the mathematics department.
#
# > **Acknowledgement:** I thank [Ian Allison](https://github.com/ianabc) and [James Colliander](http://colliand.com) of the [Pacific Institute for the Mathematical Sciences](http://www.pims.math.ca/) for building the [JupyterHub service](http://syzygy.ca) and for help with this notebook. -- I. Heisz

# %%
import numpy as np
import pandas as pd
import sys

df = pd.DataFrame()

startYear = 2014
endYear   = 2018  # The last year is not included, so 2017 means we include the 2016 collection but not 2017.

## some columns dropped here for convenience
for year in range(startYear, endYear):
#    file = 'https://s3.ca-central-1.amazonaws.com/open-data-ro/NSERC/NSERC_GRT_FYR' + str(year) + '_AWARD.csv.gz'
# https://pims-open-data.s3-us-west-2.amazonaws.com/NSERC_GRT_FYR2008_AWARD.csv
    file = 'https://pims-open-data.s3-us-west-2.amazonaws.com/NSERC_GRT_FYR' + str(year) + '_AWARD.csv'
    df = df.append(pd.read_csv(file, 
                               usecols = [1, 2, 3, 4, 5, 7, 9, 11, 13, 17, 28], 
                               encoding='latin-1'
                              )
                  )  
    print(year)
# Out:
# 2014
# 2015
# 2016
# 2017

# %%
df
# Out:
#        AwardAmount  CommitteeCode CountryEN  \
# 0            20000            187    CANADA
# 1            22000           1510    CANADA
# 2            32000           1510    CANADA
# 3            22000           1510    CANADA
# 4             4500            996    CANADA
# ...            ...            ...       ...
# 25546       122000             96    CANADA
# 25547       100000             96    CANADA
# 25548       103600             96    CANADA
# 25549         4500            996    CANADA
# 25550        20000           1509    CANADA
#
#                     Department-Département  FiscalYear-Exercice financier  \
# 0                                  Biology                           2014
# 1        Electrical & Computer Engineering                           2014
# 2      Electrical and Computer Engineering                           2014
# 3        Electrical & Computer Engineering                           2014
# 4                                Chemistry                           2014
# ...                                    ...                            ...
# 25546                  Renewable Resources                           2017
# 25547                  Renewable Resources                           2017
# 25548                  Renewable Resources                           2017
# 25549                               Botany                           2017
# 25550               Engineering, School of                           2017
#
#             Institution-Établissement               Name-Nom  OrganizationID  \
# 0                Nipissing University  (Mehes)Smith, Melanie              44
# 1              University of Waterloo          Aagaard, Mark              33
# 2      University of British Columbia            Aamodt, Tor               2
# 3               University of Toronto         Aarabi, Parham              31
# 4       The King's University College       Aarbo, Alyxandra            3333
# ...                               ...                    ...             ...
# 25546           University of Alberta        Zwiazek, Janusz               9
# 25547           University of Alberta        Zwiazek, Janusz               9
# 25548           University of Alberta        Zwiazek, Janusz               9
# 25549  University of British Columbia    Zwimpfer, Charlotte               2
# 25550            University of Guelph        Zytner, Richard              24
#
#                                           ProgramNameEN  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 25546     Collaborative Research and Development Grants
# 25547     Collaborative Research and Development Grants
# 25548     Collaborative Research and Development Grants
# 25549  University Undergraduate Student Research Awards
# 25550             Discovery Grants Program - Individual
#
#                                           ProgramNaneEN        ProvinceEN  \
# 0                              Postdoctoral Fellowships           Ontario
# 1                 Discovery Grants Program - Individual           Ontario
# 2                 Discovery Grants Program - Individual  British Columbia
# 3                 Discovery Grants Program - Individual           Ontario
# 4      University Undergraduate Student Research Awards           Alberta
# ...                                                 ...               ...
# 25546                                               NaN           Alberta
# 25547                                               NaN           Alberta
# 25548                                               NaN           Alberta
# 25549                                               NaN  British Columbia
# 25550                                               NaN           Ontario
#
#                       ResearchSubjectEN
# 0                     Molecular biology
# 1                     Computer hardware
# 2      Computer architecture and design
# 3             Digital signal processing
# 4                    Physical chemistry
# ...                                 ...
# 25546             Plant and treebiology
# 25547             Plant and treebiology
# 25548                     Not available
# 25549             Evolution and ecology
# 25550                    Bioremediation
#
# [99451 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['AwardAmount', 'CommitteeCode', 'CountryEN', 'Department-Département',
#        'FiscalYear-Exercice financier', 'Institution-Établissement',
#        'Name-Nom', 'OrganizationID', 'ProgramNameEN', 'ProgramNaneEN',
#        'ProvinceEN', 'ResearchSubjectEN'],
#       dtype='object')

# %%
## Rename columns for better readability.
df.columns = ['Name', 'Department', 'OrganizationID',
       'Institution', 'ProvinceEN', 'CountryEN',
       'FiscalYear', 'AwardAmount', 'ProgramNaneEN',
       'Committee', 'ResearchSubjectEN']

# %%
df.columns = ['AwardAmount', 'Committee', 'CountryEN', 'Department',
       'FiscalYear', 'Institution',
       'Name', 'OrganizationID', 'ProgramNameEN', 'ProgramNaneEN',
       'ProvinceEN', 'ResearchSubjectEN']

# %%
selectedData = df
selectedData = selectedData.loc[(selectedData['Committee'] == 1508)]

# %%
# remove people in the math department
subject = 'Math'
selectedData = selectedData[selectedData['Department'].str.contains(subject)==False]

# remove people in the statistics department
subject = 'Stat'
selectedData = selectedData[selectedData['Department'].str.contains(subject)==False]

# %%
selectedData = selectedData.drop('Committee', axis=1)
selectedData
# Out:
#        AwardAmount CountryEN  \
# 80           28000    CANADA
# 289          28000    CANADA
# 1922         14000    CANADA
# 2194         11000    CANADA
# 2552         23000    CANADA
# ...            ...       ...
# 24509        18000    CANADA
# 24539        14000    CANADA
# 24938        18000    CANADA
# 25416        11000    CANADA
# 25499        11000    CANADA
#
#                                               Department  FiscalYear  \
# 80     Epidemiology, Biostatistics and Occupational H...        2014
# 289                               No Department/Division        2014
# 1922   Ottawa Institute of Systems Biology; Departmen...        2014
# 2194                                  Faculty of Science        2014
# 2552                              mathematics department        2014
# ...                                                  ...         ...
# 24509  Pharmacy, Leslie Dan Faculty of - Pharmacy, Le...        2017
# 24539          Research, Office of - Research, Office of        2017
# 24938        Medicine, Faculty of - Medicine, Faculty of        2017
# 25416               Science and Engineering , Faculty of        2017
# 25499                     Epidemiology and Biostatistics        2017
#
#                                          Institution                  Name  \
# 80                                 McGill University  Abrahamowicz, Michal
# 289                              McMaster University        Alama, Stanley
# 1922                            University of Ottawa         Bickel, David
# 2194   University of Ontario Institute of Technology    Bohun, Christopher
# 2552                          University of Waterloo         Boyle, Phelim
# ...                                              ...                   ...
# 24509                         University of Waterloo   Wong, WilliamWaiLun
# 24539                  University of Western Ontario     Woolford, Douglas
# 24938            Memorial University of Newfoundland           Yi, Yanqing
# 25416                                York University          Zhu, Hongmei
# 25499                  University of Western Ontario        Zou, Guangyong
#
#        OrganizationID                          ProgramNameEN  \
# 80                 61                                    NaN
# 289                27                                    NaN
# 1922               28                                    NaN
# 2194            19222                                    NaN
# 2552               33                                    NaN
# ...               ...                                    ...
# 24509              33  Discovery Grants Program - Individual
# 24539              36  Discovery Grants Program - Individual
# 24938              89  Discovery Grants Program - Individual
# 25416              38  Discovery Grants Program - Individual
# 25499              36  Discovery Grants Program - Individual
#
#                                ProgramNaneEN                 ProvinceEN  \
# 80     Discovery Grants Program - Individual                     Québec
# 289    Discovery Grants Program - Individual                    Ontario
# 1922   Discovery Grants Program - Individual                    Ontario
# 2194   Discovery Grants Program - Individual                    Ontario
# 2552   Discovery Grants Program - Individual                    Ontario
# ...                                      ...                        ...
# 24509                                    NaN                    Ontario
# 24539                                    NaN                    Ontario
# 24938                                    NaN  Newfoundland and Labrador
# 25416                                    NaN                    Ontario
# 25499                                    NaN                    Ontario
#
#                                 ResearchSubjectEN
# 80                     Statistics and probability
# 289    Asymptotics and applied classical analysis
# 1922                           Statistical theory
# 2194                       Mathematical modelling
# 2552                          Applied probability
# ...                                           ...
# 24509                          Applied statistics
# 24539                          Applied statistics
# 24938                          Applied statistics
# 25416                                  Algorithms
# 25499                               Biostatistics
#
# [400 rows x 11 columns]

# %% [markdown]
# ## Institution Orphans

# %%
pims_sites = ['SFU', 'UA', 'UBC', 'UC', 'UL', 'UM', 'UR', 'US', 'UV']

# %%
org_id = {'SFU': 5,
          'UA': 9,
          'UBC': 2,
          'UC': 11,
          'UL': 12,
          'UM': 19,
          'UR': 17,
          'US': 16,
          'UV': 7}

# %%
## Localize to single institution (e.g. UA)
df = selectedData.loc[(selectedData['OrganizationID'] == org_id['UC'])]
df.drop(['ProvinceEN', 'CountryEN', 'OrganizationID', 'Institution'], axis = 1)
# Out:
#        AwardAmount                                         Department  \
# 5129         25000  Veterinary Medicine, Faculty of - Veterinary M...
# 12942        13000                                Oncology - Oncology
# 5205         25000  Veterinary Medicine, Faculty of - Veterinary M...
# 13184        13000                                Oncology - Oncology
# 5369         25000  Veterinary Medicine, Faculty of - Veterinary M...
# 13568        13000                                Oncology - Oncology
# 19995        14000  Community Health Sciences - Community Health S...
#
#        FiscalYear              Name                          ProgramNameEN  \
# 5129         2015      Deardon, Rob                                    NaN
# 12942        2015      Li, Haocheng                                    NaN
# 5205         2016      Deardon, Rob                                    NaN
# 13184        2016      Li, Haocheng                                    NaN
# 5369         2017      Deardon, Rob  Discovery Grants Program - Individual
# 13568        2017      Li, Haocheng  Discovery Grants Program - Individual
# 19995        2017  Sajobi, Tolulope  Discovery Grants Program - Individual
#
#                                ProgramNaneEN        ResearchSubjectEN
# 5129   Discovery Grants Program - Individual            Biostatistics
# 12942  Discovery Grants Program - Individual  Nonparametric inference
# 5205   Discovery Grants Program - Individual            Biostatistics
# 13184  Discovery Grants Program - Individual  Nonparametric inference
# 5369                                     NaN       Applied statistics
# 13568                                    NaN            Biostatistics
# 19995                                    NaN       Applied statistics

# %%
## List the records of orphans for each PIMS site
for inst in pims_sites:
    orph_inst = selectedData.loc[(selectedData['OrganizationID'] == org_id[inst])]
    orph_inst.drop(['ProvinceEN', 'CountryEN', 'OrganizationID', 'Institution'], axis = 1)
    display(orph_inst)
# Out:
#        AwardAmount CountryEN  \
# 7571         14000    CANADA
# 7614         14000    CANADA
# 14531        17000    CANADA
# 7778         14000    CANADA
# 14786        17000    CANADA
# 8115         14000    CANADA
# 15198        17000    CANADA
#
#                                               Department  FiscalYear  \
# 7571                                           Economics        2014
# 7614                                           Economics        2015
# 14531  Health Sciences, Faculty of - Health Sciences,...        2015
# 7778                                           Economics        2016
# 14786  Health Sciences, Faculty of - Health Sciences,...        2016
# 8115                                           Economics        2017
# 15198  Health Sciences, Faculty of - Health Sciences,...        2017
#
#                    Institution                  Name  OrganizationID  \
# 7571   Simon Fraser University       Gencay, Ramazan               5
# 7614   Simon Fraser University       Gencay, Ramazan               5
# 14531  Simon Fraser University  McCandless, Lawrence               5
# 7778   Simon Fraser University       Gencay, Ramazan               5
# 14786  Simon Fraser University  McCandless, Lawrence               5
# 8115   Simon Fraser University       Gencay, Ramazan               5
# 15198  Simon Fraser University  McCandless, Lawrence               5
#
#                                ProgramNameEN  \
# 7571                                     NaN
# 7614                                     NaN
# 14531                                    NaN
# 7778                                     NaN
# 14786                                    NaN
# 8115   Discovery Grants Program - Individual
# 15198  Discovery Grants Program - Individual
#
#                                ProgramNaneEN        ProvinceEN  \
# 7571   Discovery Grants Program - Individual  British Columbia
# 7614   Discovery Grants Program - Individual  British Columbia
# 14531  Discovery Grants Program - Individual  British Columbia
# 7778   Discovery Grants Program - Individual  British Columbia
# 14786  Discovery Grants Program - Individual  British Columbia
# 8115                                     NaN  British Columbia
# 15198                                    NaN  British Columbia
#
#              ResearchSubjectEN
# 7571   Nonparametric inference
# 7614   Nonparametric inference
# 14531            Biostatistics
# 7778   Nonparametric inference
# 14786            Biostatistics
# 8115   Nonparametric inference
# 15198            Biostatistics
#        AwardAmount CountryEN                                       Department  \
# 9248         12000    CANADA                                        Dentistry
# 18587        12000    CANADA                                       Pediatrics
# 18875        15000    CANADA                                Campus Saint-Jean
# 18491  Discovery Grants Program - Individual  British Columbia
# 6862   Discovery Grants Program - Individual  British Columbia
# 10838  Discovery Grants Program - Individual  British Columbia
# 13361  Discovery Grants Program - Individual  British Columbia
# 13800  Discovery Grants Program - Individual  British Columbia
# 18679  Discovery Grants Program - Individual  British Columbia
# 19322  Discovery Grants Program - Individual  British Columbia
# 6962   Discovery Grants Program - Individual  British Columbia
# 11068  Discovery Grants Program - Individual  British Columbia
# 13602  Discovery Grants Program - Individual  British Columbia
# 14039  Discovery Grants Program - Individual  British Columbia
# 19131  Discovery Grants Program - Individual  British Columbia
# 19786  Discovery Grants Program - Individual  British Columbia
# 7281                                     NaN  British Columbia
# 11432                                    NaN  British Columbia
# 14045                                    NaN  British Columbia
# 14483                                    NaN  British Columbia
# 20240                                    NaN  British Columbia
# 20870                                    NaN  British Columbia
#
#                 ResearchSubjectEN
# 3703      Nonparametric inference
# 10737          Statistical theory
# 13605               Biostatistics
# 18491                     Algebra
# 6862   Statistics and probability
# 10838          Statistical theory
# 13361          Applied statistics
# 13800               Biostatistics
# 18679                     Algebra
# 19322          Applied statistics
# 6962   Statistics and probability
# 11068          Statistical theory
# 13602          Applied statistics
# 14039               Biostatistics
# 19131                     Algebra
# 19786          Applied statistics
# 7281   Statistics and probability
# 11432          Statistical theory
# 14045          Applied statistics
# 14483               Biostatistics
# 20240          Applied statistics
# 20870        Mathematical physics
#        AwardAmount CountryEN  \
# 5129         25000    CANADA
# 12942        13000    CANADA
# 5205         25000    CANADA
# 13184        13000    CANADA
# 5369         25000    CANADA
# 13568        13000    CANADA
# 19995        14000    CANADA
#
#                                               Department  FiscalYear  \
# 5129   Veterinary Medicine, Faculty of - Veterinary M...        2015
# 12942                                Oncology - Oncology        2015
# 5205   Veterinary Medicine, Faculty of - Veterinary M...        2016
# 13184                                Oncology - Oncology        2016
# 5369   Veterinary Medicine, Faculty of - Veterinary M...        2017
# 13568                                Oncology - Oncology        2017
# 19995  Community Health Sciences - Community Health S...        2017
#
#                  Institution              Name  OrganizationID  \
# 5129   University of Calgary      Deardon, Rob              11
# 12942  University of Calgary      Li, Haocheng              11
# 5205   University of Calgary      Deardon, Rob              11
# 13184  University of Calgary      Li, Haocheng              11
# 5369   University of Calgary      Deardon, Rob              11
# 13568  University of Calgary      Li, Haocheng              11
# 19995  University of Calgary  Sajobi, Tolulope              11
#
#                                ProgramNameEN  \
# 5129                                     NaN
# 12942                                    NaN
# 5205                                     NaN
# 13184                                    NaN
# 5369   Discovery Grants Program - Individual
# 13568  Discovery Grants Program - Individual
# 19995  Discovery Grants Program - Individual
#
#                                ProgramNaneEN ProvinceEN  \
# 5129   Discovery Grants Program - Individual    Alberta
# 12942  Discovery Grants Program - Individual    Alberta
# 5205   Discovery Grants Program - Individual    Alberta
# 13184  Discovery Grants Program - Individual    Alberta
# 5369                                     NaN    Alberta
# 13568                                    NaN    Alberta
# 19995                                    NaN    Alberta
#
#              ResearchSubjectEN
# 5129             Biostatistics
# 12942  Nonparametric inference
# 5205             Biostatistics
# 13184  Nonparametric inference
# 5369        Applied statistics
# 13568            Biostatistics
# 19995       Applied statistics
# Empty DataFrame
# Columns: [AwardAmount, CountryEN, Department, FiscalYear, Institution, Name, OrganizationID, ProgramNameEN, ProgramNaneEN, ProvinceEN, ResearchSubjectEN]
# Index: []
#        AwardAmount CountryEN  \
# 7098         17000    CANADA
# 17276        12000    CANADA
# 21541        17000    CANADA
# 17457        12000    CANADA
# 21769        17000    CANADA
# 24366        13000    CANADA
# 7231         17000    CANADA
# 9086         16700    CANADA
# 22287        27000    CANADA
# 24975        13000    CANADA
# 7551         17000    CANADA
# 9408         16700    CANADA
# 20672        14000    CANADA
# 22708        27000    CANADA
#
#                                               Department  FiscalYear  \
# 7098               Agribusiness & Agricultural Economics        2014
# 17276                                   Computer Science        2014
# 21541                          Community Health Sciences        2014
# 17457                                   Computer Science        2015
# 21769                          Community Health Sciences        2015
# 24366  Warren Centre for Actuarial Studies and Resear...        2015
# 7231               Agribusiness & Agricultural Economics        2016
# 9086    Warren Centre for Actuarial Studies and Research        2016
# 22287  Community Health Sciences - Community Health S...        2016
# 24975  Warren Centre for Actuarial Studies and Resear...        2016
# 7551               Agribusiness & Agricultural Economics        2017
# 9408    Warren Centre for Actuarial Studies and Research        2017
# 20672      Physics and Astronomy - Physics and Astronomy        2017
# 22708  Community Health Sciences - Community Health S...        2017
#
#                   Institution                Name  OrganizationID  \
# 7098   University of Manitoba      Frank, Julieta              19
# 17276  University of Manitoba     Pizzi, Nicolino              19
# 21541  University of Manitoba     Torabi, Mahmoud              19
# 17457  University of Manitoba     Pizzi, Nicolino              19
# 21769  University of Manitoba     Torabi, Mahmoud              19
# 24366  University of Manitoba           Zhou, Rui              19
# 7231   University of Manitoba      Frank, Julieta              19
# 9086   University of Manitoba        Hao, Xuemiao              19
# 22287  University of Manitoba     Torabi, Mahmoud              19
# 24975  University of Manitoba           Zhou, Rui              19
# 7551   University of Manitoba      Frank, Julieta              19
# 9408   University of Manitoba        Hao, Xuemiao              19
# 20672  University of Manitoba  Shamseddine, Khodr              19
# 22708  University of Manitoba     Torabi, Mahmoud              19
#
#                                ProgramNameEN  \
# 7098                                     NaN
# 17276                                    NaN
# 21541                                    NaN
# 17457                                    NaN
# 21769                                    NaN
# 24366                                    NaN
# 7231                                     NaN
# 9086                                     NaN
# 22287                                    NaN
# 24975                                    NaN
# 7551   Discovery Grants Program - Individual
# 9408   Discovery Grants Program - Individual
# 20672  Discovery Grants Program - Individual
# 22708  Discovery Grants Program - Individual
#
#                                ProgramNaneEN ProvinceEN  \
# 7098   Discovery Grants Program - Individual   Manitoba
# 17276  Discovery Grants Program - Individual   Manitoba
# 21541  Discovery Grants Program - Individual   Manitoba
# 17457  Discovery Grants Program - Individual   Manitoba
# 21769  Discovery Grants Program - Individual   Manitoba
# 24366  Discovery Grants Program - Individual   Manitoba
# 7231   Discovery Grants Program - Individual   Manitoba
# 9086   Discovery Grants Program - Individual   Manitoba
# 22287  Discovery Grants Program - Individual   Manitoba
# 24975  Discovery Grants Program - Individual   Manitoba
# 7551                                     NaN   Manitoba
# 9408                                     NaN   Manitoba
# 20672                                    NaN   Manitoba
# 22708                                    NaN   Manitoba
#
#             ResearchSubjectEN
# 7098     Time series analysis
# 17276  Mathematical modelling
# 21541      Survey methodology
# 17457  Mathematical modelling
# 21769      Survey methodology
# 24366      Applied statistics
# 7231     Time series analysis
# 9086      Applied probability
# 22287      Applied statistics
# 24975      Applied statistics
# 7551     Time series analysis
# 9408      Applied probability
# 20672      Classical analysis
# 22708      Applied statistics
# Empty DataFrame
# Columns: [AwardAmount, CountryEN, Department, FiscalYear, Institution, Name, OrganizationID, ProgramNameEN, ProgramNaneEN, ProvinceEN, ResearchSubjectEN]
# Index: []
#       AwardAmount CountryEN                Department  FiscalYear  \
# 6712        15000    CANADA  Public Health, School of        2014
# 6704        15000    CANADA  Public Health, School of        2015
# 6810        15000    CANADA  Public Health, School of        2016
# 7125        15000    CANADA  Public Health, School of        2017
#
#                      Institution            Name  OrganizationID  \
# 6712  University of Saskatchewan  Feng, CindyXin              16
# 6704  University of Saskatchewan  Feng, CindyXin              16
# 6810  University of Saskatchewan  Feng, CindyXin              16
# 7125  University of Saskatchewan  Feng, CindyXin              16
#
#                               ProgramNameEN  \
# 6712                                    NaN
# 6704                                    NaN
# 6810                                    NaN
# 7125  Discovery Grants Program - Individual
#
#                               ProgramNaneEN    ProvinceEN  \
# 6712  Discovery Grants Program - Individual  Saskatchewan
# 6704  Discovery Grants Program - Individual  Saskatchewan
# 6810  Discovery Grants Program - Individual  Saskatchewan
# 7125                                    NaN  Saskatchewan
#
#                ResearchSubjectEN
# 6712  Statistics and probability
# 6704  Statistics and probability
# 6810  Statistics and probability
# 7125  Statistics and probability
# Empty DataFrame
# Columns: [AwardAmount, CountryEN, Department, FiscalYear, Institution, Name, OrganizationID, ProgramNameEN, ProgramNaneEN, ProvinceEN, ResearchSubjectEN]
# Index: []

# %%
## List the names of orphans for each PIMS site
for inst in pims_sites:
    orph_inst = selectedData.loc[(selectedData['OrganizationID'] == org_id[inst])]
    orph_inst.drop(['ProvinceEN', 'CountryEN', 'OrganizationID', 'Institution'], axis = 1)
    print(inst,orph_inst['Name'].unique())
# Out:
# SFU ['Gencay, Ramazan' 'McCandless, Lawrence']
# UA ['Heo, Giseon' 'Rosychuk, Rhonda' 'Safouhi, Hassan' 'Belhamadia, Youssef']
# UBC ['Chen, Jiahua' 'Kasahara, Hiroyuki' 'MacNab, Ying' 'Rolfsen, Dale'
#  'Fisher, Adlai' 'Loeppky, Jason' 'Savalei, Victoria' 'Shizgal, Bernard']
# UC ['Deardon, Rob' 'Li, Haocheng' 'Sajobi, Tolulope']
# UL []
# UM ['Frank, Julieta' 'Pizzi, Nicolino' 'Torabi, Mahmoud' 'Zhou, Rui'
#  'Hao, Xuemiao' 'Shamseddine, Khodr']
# UR []
# US ['Feng, CindyXin']
# UV []
