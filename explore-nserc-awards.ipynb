# %% [markdown]
# <img src="http://www.nserc-crsng.gc.ca/_gui/wmms.gif" alt="Canada logo" align="right">
#
# <br>
#
# <img src="http://www.triumf.ca/sites/default/files/styles/gallery_large/public/images/nserc_crsng.gif?itok=H7AhTN_F" alt="NSERC logo" align="right" width = 90>
#
#
#
# # Exploring NSERC Awards Data
#
#
# Canada's [Open Government Portal](http://open.canada.ca/en) includes [NSERC Awards Data](http://open.canada.ca/data/en/dataset/c1b0f627-8c29-427c-ab73-33968ad9176e) from 1991 through 2014. The [2015](http://www.nserc-crsng.gc.ca/NSERC-CRSNG/FundingDecisions-DecisionsFinancement/ResearchGrants-SubventionsDeRecherche/ResultsGSC-ResultatsCSS_eng.asp?Year=2015) and [2016](http://www.nserc-crsng.gc.ca/NSERC-CRSNG/FundingDecisions-DecisionsFinancement/ResearchGrants-SubventionsDeRecherche/ResultsGSC-ResultatsCSS_eng.asp?Year=2016) data are available separately.
#
# The awards data (in .csv format) were copied to an [Amazon Web Services S3 bucket](http://docs.aws.amazon.com/AmazonS3/latest/dev/UsingBucket.html). This open Jupyter notebook starts an exploration of the NSERC investment portfolio during the 1995 -- 2014 epoch. The notebook assumes that you have your AWS keys setup in `~/.aws/credentials`. See the [boto3 docs](http://boto3.readthedocs.io/en/latest/guide/configuration.html) for more information on configuration of credentials. (If you'd like access to the data hosted on S3, please contact [James Colliander](http://colliand.com).)
#
# > **Acknowledgement:** I thank [Ian Allison](https://github.com/ianabc) of the [Pacific Institute for the Mathematical Sciences](http://www.pims.math.ca/) for building the [JupyterHub service](https://pims.jupyter.ca) and for help with this notebook. -- J. Colliander

# %%
## Import some Python resources for data and interactive plots.
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import widgets
import numpy as np
import seaborn as sns

import sys

from IPython.display import display, clear_output
from ipywidgets import widgets

sns.set_style("darkgrid")

# %matplotlib inline
plt.rcParams['figure.figsize'] = 10, 6

# %%
## Import the tools for accessing data hosted on AWS S3.
import boto3
import botocore

## name the bucket containing the data
nsercBucket='pims-open-data'

s3 = boto3.client('s3')
exists = True

try:
    s3.head_bucket(Bucket=nsercBucket)
except botocore.exceptions.ClientError as e:
    # If a client error is thrown, then check that it was a 404 error.
    # If it was a 404 error, then the bucket does not exist.
    error_code = int(e.response['Error']['Code'])
    if error_code == 404:
        exists = False

# %%
## Bring in a selection of the NSERC awards data starting with 1995 and ending with 2014.
## Throw away as much as you can to keep the DataFrame small enough to manipulate using a laptop.

startYear=1995
endYear=2015  ## This means we include the 2014 collection but not 2015.

nserc = []
institutionAwards = []

s3 = boto3.resource('s3')
bucket = s3.Bucket(nsercBucket)

for year in range(startYear, endYear):
    obj = boto3.client('s3').get_object(
        Bucket=nsercBucket, Key='NSERC_GRT_FYR'+str(year)+'_AWARD.csv')
    df = pd.read_csv(obj['Body'], 
                     encoding='latin1', 
                     usecols = [1, 2, 3, 4, 5, 7, 9, 11, 12, 13, 28],
                    )
    nserc.append(df)
    df.columns = ['Name', 'Department', 'OrganizationID',
                 'Institution', 'ProvinceEN', 'CountryEN',
                 'FiscalYear', 'AwardAmount', 'ProgramID',
                 'ProgramNameEN','ResearchSubjectEN']   ## Rename various columns for easier access.
    print(year)
# Out:
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014

# %%
## Again, throw away some superfluous data to minimize impact on memory.
try:
    nsercDF = pd.concat(nserc)
    del(nserc)
except NameError:
    print("Namespace already cleaned")

print("DataFrame: {:4.2f} Mb".format(sys.getsizeof(nsercDF) / (1024. * 1024)))  ##Quantify data stored in memory.
# Out:
# DataFrame: 249.77 Mb

# %%
## These are the columns in our data table.
nsercDF.columns
# Out:
# Index(['Name', 'Department', 'OrganizationID', 'Institution', 'ProvinceEN',
#        'CountryEN', 'FiscalYear', 'AwardAmount', 'ProgramID', 'ProgramNameEN',
#        'ResearchSubjectEN'],
#       dtype='object')

# %%
## This is what the data looks like.
nsercDF
# Out:
#                              Name  \
# 0                 Aarssen, Lonnie
# 1                  Abbott, Harvey
# 2                    Abbott, Sean
# 3                  Abcarius, John
# 4                Abcarius, Nicole
# 5                   Abdalla, Hany
# 6                 AbdelAziz, Alaa
# 7                AbdElHalim, Omar
# 8        AbdelRahman, AbdelFattah
# 9              Abdelrahman, Tarek
# 10             AbdelSayed, George
# 11               Abdous, Belkacem
# 12                   AbdulBaki, I
# 13            Abecassis, Maurissa
# 14                Abedi, SeiJalal
# 15                    Abid, Lamia
# 16                 Ableson, AlanD
# 17           Abouatallah, Ghassan
# 18              Abouatallah, Rami
# 19              Abouchacra, Rabih
# 20             AbouHaidar, Mounir
# 21                AbouJeyab, Rola
# 22                 Aboulazm, Azmy
# 23         Aboulhamid, ElMostapha
# 24                AboulHosn, Wafa
# 25              Aboulnasr, Tyseer
# 26               AbouRabia, Osman
# 27                Abourahma, Heba
# 28               AbouRizk, Simaan
# 29               AbouRizk, Simaan
# ...                           ...
# 24229               Zowmi, Aniqah
# 24230                    Zu, Jean
# 24231                    Zu, Jean
# 24232             Zucker, Jeffery
# 24233              Zuend, Andreas
# 24234            Zuliani, Jocelyn
# 24235            Zuliani, Jocelyn
# 24236        Zulkernine, Mohammad
# 24237        Zulkernine, Mohammad
# 24238              Zumer, Jeremie
# 24239               Zung, Jessica
# 24240  ZunigaPflucker, JuanCarlos
# 24241               Zuo, Mingjian
# 24242               Zuo, Mingjian
# 24243               Zuo, Mingjian
# 24244                Zurob, Hatem
# 24245                Zurob, Hatem
# 24246                Zurob, Hatem
# 24247          Zvengrowski, Peter
# 24248              Zwambag, Derek
# 24249         Zwanenburg, Natalie
# 24250          Zwanenburg, Philip
# 24251          Zwanenburg, Philip
# 24252            Zwanziger, Josef
# 24253            Zwanziger, Josef
# 24254             Zwiazek, Janusz
# 24255             Zwiazek, Janusz
# 24256             Zwiazek, Janusz
# 24257         Zygowska, Alexandra
# 24258             Zytner, Richard
#
#                                               Department  OrganizationID  \
# 19                         McGill University                     Québec
# 20                     University of Toronto                    Ontario
# 21       Technical University of Nova Scotia                Nova Scotia
# 22       Memorial University of Newfoundland  Newfoundland and Labrador
# 23                    Université de Montréal                     Québec
# 24                         McGill University                     Québec
# 25                      University of Ottawa                    Ontario
# 26          Laurentian University of Sudbury                    Ontario
# 27                   Saint Mary's University                Nova Scotia
# 28                     University of Alberta                    Alberta
# 29                     University of Alberta                    Alberta
# ...                                      ...                        ...
# 24229                       Brock University                    Ontario
# 24230                  University of Toronto                    Ontario
# 24231                  University of Toronto                    Ontario
# 24232                    McMaster University                    Ontario
# 24233                      McGill University                     Québec
# 24234                  University of Toronto                    Ontario
# 24235                  University of Toronto                    Ontario
# 24236                     Queen's University                    Ontario
# 24237                     Queen's University                    Ontario
# 24238                 Université de Montréal                     Québec
# 24239                  University of Toronto                    Ontario
# 24240                  University of Toronto                    Ontario
# 24241                  University of Alberta                    Alberta
# 24242                  University of Alberta                    Alberta
# 24243                  University of Alberta                    Alberta
# 24244                    McMaster University                    Ontario
# 24245                    McMaster University                    Ontario
# 24246                    McMaster University                    Ontario
# 24247                  University of Calgary                    Alberta
# 24248                   University of Guelph                    Ontario
# 24249                    Lakehead University                    Ontario
# 24250                      McGill University                     Québec
# 24251                      McGill University                     Québec
# 24252                   Dalhousie University                Nova Scotia
# 24253                   Dalhousie University                Nova Scotia
# 24254                  University of Alberta                    Alberta
# 24255                  University of Alberta                    Alberta
# 24256                  University of Alberta                    Alberta
# 24257                  University of Windsor                    Ontario
# 24258                   University of Guelph                    Ontario
#
#            CountryEN  FiscalYear  AwardAmount ProgramID  \
# 0             CANADA        1995        41400    RGPIN
# 1             CANADA        1995        14000    RGPIN
# 2             CANADA        1995         5755    PGS
# 3             CANADA        1995        10380    PGS
# 4             CANADA        1995         3600    URI
# 5             CANADA        1995        20985    PDF
# 6             CANADA        1995        32264    RGPIN
# 7             CANADA        1995        20000    RGPIN
# 8             CANADA        1995        15000    RGPIN
# 9             CANADA        1995         9500    RGPIN
# 10            CANADA        1995        15000    RGPIN
# 11            CANADA        1995        10000    RGPIN
# 12            CANADA        1995         9886    IPS
# 13     UNITED STATES        1995        21300    SES
# 14            CANADA        1995         5822    PGS
# 15            CANADA        1995        10380    PGS
# 16            CANADA        1995        10380    PGS
# 17            CANADA        1995         3600    URI
# 18            CANADA        1995         3600    URU
# 19            CANADA        1995        15600    PGS
# 20            CANADA        1995        49000    RGPIN
# 21            CANADA        1995        15600    PGS
# 22            CANADA        1995        16000    RGPIN
# 23            CANADA        1995         7500    RGPIN
# 24            CANADA        1995        17400    PGS
# 25            CANADA        1995        20592    RGPIN
# 26            CANADA        1995         5700    RGPIN
# 27            CANADA        1995         3600    URU
# 28            CANADA        1995        80000    CRDPJ
# 29            CANADA        1995        19600    RGPIN
# ...              ...         ...          ...       ...
# 24229         CANADA        2014         4500       URU
# 24230         CANADA        2014        25000       EGP
# 24231         CANADA        2014        45000     RGPIN
# 24232         CANADA        2014        15000     RGPIN
# 24233         CANADA        2014        35000     RGPIN
# 24234         CANADA        2014         6000      CFSS
# 24235         CANADA        2014        35000      CGSD
# 24236         CANADA        2014       100000       CRC
# 24237         CANADA        2014        26000     RGPIN
# 24238         CANADA        2014         4500       URU
# 24239         CANADA        2014         4500       URU
# 24240         CANADA        2014        41000     RGPIN
# 24241         CANADA        2014        24950       EGP
# 24242         CANADA        2014        24930       EGP
# 24243         CANADA        2014        79000     RGPIN
# 24244         CANADA        2014        58667     CRDPJ
# 24245         CANADA        2014        39000     CRDPJ
# 24246         CANADA        2014        40000     RGPIN
# 24247         CANADA        2014        12000     RGPIN
# 24248         CANADA        2014        21000      PGSD
# 24249         CANADA        2014         4500       URU
# 24250         CANADA        2014         4500       URU
# 24251         CANADA        2014        17500      CGSM
# 24252         CANADA        2014        99000     RGPIN
# 24253         CANADA        2014       200000       CRC
# 24254         CANADA        2014        27000     RGPIN
# 24255         CANADA        2014       131500     CRDPJ
# 24256         CANADA        2014        38500     CRDPJ
# 24257         CANADA        2014         4500       URU
# 24258         CANADA        2014        20000     RGPIN
#
#                                            ProgramNameEN  \
# 0                  Discovery Grants Program - Individual
# 1                  Discovery Grants Program - Individual
# 2                              Postgraduate Scholarships
# 3                              Postgraduate Scholarships
# 4       Industrial Undergraduate Student Research Awards
# 5                               Postdoctoral Fellowships
# 6                  Discovery Grants Program - Individual
# 7                  Discovery Grants Program - Individual
# 8                  Discovery Grants Program - Individual
# 9                  Discovery Grants Program - Individual
# 10                 Discovery Grants Program - Individual
# 11                 Discovery Grants Program - Individual
# 12                  Industrial Postgraduate Scholarships
# 13             1967 Science and Engineering Scholarships
# 14                             Postgraduate Scholarships
# 15                             Postgraduate Scholarships
# 16                             Postgraduate Scholarships
# 17      Industrial Undergraduate Student Research Awards
# 18      University Undergraduate Student Research Awards
# 19                             Postgraduate Scholarships
# 20                 Discovery Grants Program - Individual
# 21                             Postgraduate Scholarships
# 22                 Discovery Grants Program - Individual
# 23                 Discovery Grants Program - Individual
# 24                             Postgraduate Scholarships
# 25                 Discovery Grants Program - Individual
# 26                 Discovery Grants Program - Individual
# 27      University Undergraduate Student Research Awards
# 28         Collaborative Research and Development Grants
# 29                 Discovery Grants Program - Individual
# ...                                                  ...
# 24229   University Undergraduate Student Research Awards
# 24230  Engage Grants Program                         ...
# 24231              Discovery Grants Program - Individual
# 24232              Discovery Grants Program - Individual
# 24233              Discovery Grants Program - Individual
# 24234  Canadian Graduate Scholarships Foreign Study S...
# 24235  Alexander Graham Bell Canada Graduate Scholars...
# 24236                             Canada Research Chairs
# 24237              Discovery Grants Program - Individual
# 24238   University Undergraduate Student Research Awards
# 24239   University Undergraduate Student Research Awards
# 24240              Discovery Grants Program - Individual
# 24241  Engage Grants Program                         ...
# 24242  Engage Grants Program                         ...
# 24243              Discovery Grants Program - Individual
# 24244      Collaborative Research and Development Grants
# 24245      Collaborative Research and Development Grants
# 24246              Discovery Grants Program - Individual
# 24247              Discovery Grants Program - Individual
# 24248               Postgraduate Scholarships - Doctoral
# 24249   University Undergraduate Student Research Awards
# 24250   University Undergraduate Student Research Awards
# 24251  Alexander Graham Bell Canada Graduate Scholars...
# 24252              Discovery Grants Program - Individual
# 24253                             Canada Research Chairs
# 24254              Discovery Grants Program - Individual
# 24255      Collaborative Research and Development Grants
# 24256      Collaborative Research and Development Grants
# 24257   University Undergraduate Student Research Awards
# 24258              Discovery Grants Program - Individual
#
#                                        ResearchSubjectEN
# 0                                    Terrestrial ecology
# 1                                          Combinatorics
# 2                Taxonomy, systematics and phylogenetics
# 3                                    Integrated circuits
# 4             Operations research and management science
# 5                                 Structural engineering
# 6                     Metal and organometallic chemistry
# 7                                   Structural materials
# 8             Petrology, igneous and metamorphic geology
# 9                               Software and development
# 10                                   Structural analysis
# 11                               Nonparametric inference
# 12                                         Not available
# 13                            Cognitive science -- other
# 14                                        Thermodynamics
# 15                            Statistics and probability
# 16                                   Applied mathematics
# 17                           Food science and technology
# 18                             Environmental engineering
# 19                                Communications systems
# 20                                         Not available
# 21                                         Manufacturing
# 22                                  Offshore engineering
# 23                                     Computer hardware
# 24                         Aquatic ecology and limnology
# 25                                        Circuit theory
# 26                                            Algorithms
# 27                 Crystallography -- physical chemistry
# 28               Construction engineering and management
# 29               Construction engineering and management
# ...                                                  ...
# 24229                                  Molecular biology
# 24230                                 Engineering design
# 24231             Mechanical systems and instrumentation
# 24232                              Theory of computation
# 24233    Atmospheric chemistry (including air pollution)
# 24234                               Chemical engineering
# 24235                               Chemical engineering
# 24236                             Information technology
# 24237                               Software engineering
# 24238  Artificial intelligence (computer vision, use2...
# 24239                              Evolution and ecology
# 24240                                    Gene regulation
# 24241         Operations research and management science
# 24242         Operations research and management science
# 24243         Operations research and management science
# 24244        Materials structure, properties and testing
# 24245        Materials structure, properties and testing
# 24246                   Materials science and technology
# 24247                                 Algebraic topology
# 24248                                        Kinesiology
# 24249                     Geochemistry and geochronology
# 24250                             Mechanical engineering
# 24251                                      Not available
# 24252                                 Physical chemistry
# 24253                                 Physical chemistry
# 24254                              Plant and treebiology
# 24255                              Plant and treebiology
# 24256                              Plant and treebiology
# 24257                   Animal physiology and metabolism
# 24258                                     Bioremediation
#
# [408255 rows x 11 columns]

# %% [markdown]
# ## Total Invested by NSERC Over Time

# %% [markdown]
# We accumulate the award amounts into a total sum for each year and plot these values over time. These calculations do not take inflation or other factors into account.

# %%
awardTotals = nsercDF.groupby('FiscalYear').sum()['AwardAmount']

import matplotlib.ticker as mtick

fig = plt.figure()

ax = fig.add_subplot(111)

ax.plot(awardTotals.index, awardTotals/10**6)
ax.set_ylabel('Award Total ($/M)')
ax.set_xlabel('Year')

ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%4d'))

# %% [markdown]
# ## 2014 Investments by `Institution`
#
# Let's focus in on 2014. We accumulate all the awards for each institution and sort by the resulting totals. Then, we expose an ordered list of the institutions that received the biggest investments from NSERC.

# %%
byInstitution = nsercDF[nsercDF.FiscalYear == 2014].groupby('Institution')
top10 = byInstitution.sum()['AwardAmount'].sort_values(
    ascending=False).head(n=10)
top10
# Out:
# Institution
# University of Toronto             89894358
# University of British Columbia    75418783
# University of Alberta             60280376
# University of Waterloo            59567435
# McGill University                 59203321
# Université Laval                  43043887
# McMaster University               38444093
# Queen's University                34839270
# University of Western Ontario     31639903
# University of Calgary             31470112
# Name: AwardAmount, dtype: int64

# %% [markdown]
# We set colors for these institutions to set up visualizations of the data.

# %%
institutionList = list(top10.index)
instColor = zip(institutionList, sns.color_palette())
institutionList
# Out:
# ['University of Toronto',
#  'University of British Columbia',
#  'University of Alberta',
#  'University of Waterloo',
#  'McGill University',
#  'Université Laval',
#  'McMaster University',
#  "Queen's University",
#  'University of Western Ontario',
#  'University of Calgary']

# %%
## Make a pie chart.
awards = nsercDF[nsercDF.FiscalYear == 2014].groupby(
    'Institution').sum().sort_values(
    'AwardAmount', ascending=False).head(n=10)
awards.loc[institutionList].plot.pie('AwardAmount',
                                       figsize=(8,8), legend=None)

# %%
## Make a bar chart.
a = awards.loc[institutionList]['AwardAmount']
a.plot.bar(color=sns.color_palette())

# %% [markdown]
# ## 2014 Award Totals by `Province`

# %%
byProvince = nsercDF[nsercDF.FiscalYear == 2014].groupby('ProvinceEN')
provinceAmounts = byProvince.sum()['AwardAmount'].sort_values(
    ascending=False)
provinceAmounts
# Out:
# ProvinceEN
# Ontario                      408720777
# Québec                       254239757
# British Columbia             138839981
# Alberta                      103374397
# Nova Scotia                   37018659
# Saskatchewan                  31686697
# Manitoba                      22792834
# New Brunswick                 13409680
# Newfoundland and Labrador      8770998
# Prince Edward Island           3666008
# Massachusetts                  3221392
# California                     2843547
# New York                       1303457
# Yukon                           505315
# Michigan                        410415
# New Jersey                      300500
# Pennsylvania                    260750
# Illinois                        258348
# Connecticut                     233000
# Indiana                         189500
# Maryland                        165000
# Washington                      154000
# Wisconsin                       125500
# Texas                           113787
# Rhode Island                    106750
# Colorado                        105800
# Florida                          90000
# District of Columbia             85000
# Minnesota                        83500
# Georgia                          82000
# Virginia                         61000
# New Mexico                       60000
# Arizona                          42001
# Hawaii                           42000
# North Carolina                   42000
# Oregon                           31500
# Kansas                           21000
# Maine                            21000
# Nebraska                         21000
# Ohio                             21000
# Alabama                          21000
# Idaho                            14894
# Louisiana                        10000
# Name: AwardAmount, dtype: int64

# %% [markdown]
# ## 2014 Award Totals by `ProgramName`

# %%
byProgramName = nsercDF[nsercDF.FiscalYear == 2014].groupby('ProgramNameEN')
programNameAmounts = byProgramName.sum()['AwardAmount'].sort_values(
    ascending=False)
programNameAmounts
# Out:
# ProgramNameEN
# Discovery Grants Program - Individual                                                                   318531751
# %% [markdown]
# ## Specific `Department` within an `Institution` over Time
#
# **UBC Mathematics**

# %%
ubcMath = nsercDF.loc[(nsercDF['Department'].isin(['Mathematics'])) 
            & (nsercDF['Institution'].isin(['University of British Columbia']))].groupby('FiscalYear').sum()['AwardAmount']

fig = plt.figure()

ax = fig.add_subplot(111)

ax.plot(ubcMath.index, ubcMath/10**6)
ax.set_ylabel('Award Total ($/M)')
ax.set_xlabel('Year')

ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%4d'))

# %% [markdown]
# ## Big Winners over Time

# %%
byName = nsercDF.loc[(nsercDF['AwardAmount'] > 1000000)].groupby('Name')
byName.sum().sort_values(
    'AwardAmount', ascending=False).head(n=50)
# Out:
#                       OrganizationID  FiscalYear  AwardAmount
# Name
# Hormes, Josef                    160       20105     99732800
# Gupta, Arvind                  83296       40142     89693750
# Frise, Peter                     629       34128     63289750
# McWalter, Ian                    232       16084     60172580
# Fortier, Louis                   816       32112     52423909
# Barge, Brian                   48872       16021     49400000
# Thomlinson, William               80       10025     46550000
# Fedosejevs, Robert               459       18063     35872000
# McDonald, Arthur                 377       26014     32863300
# Mufti, Aftab                     171       18036     27702000
# Rogers, Harry                  10404       11985     27580000
# Burton, Howard                 87010       10020     25000000
# Servos, Mark                     297       18059     24560250
# Salama, Andre                  39580       19995     22580000
# Wallace, Douglas                 632       16100     21294833
# Chrisman, Nicholas               408       16060     21286250
# Clowes, Ronald                    12       11985     21105000
# Smith, Donald                    427       14074     20432287
# Yada, Rickey                     192       16052     19470000
# Eyton, Anthony                  6936        8010     17325000
# Larter, Stephen                   55       10055     16926314
# Marsh, AH                      12247        5993     15900000
# Orr, Robert                      164       18030     15500500
# Booth, Kellogg                    12       12069     15255000
# Cashman, Neil                     14       14056     14696000
# Bourbonnais, Normand           63924        4021     14078965
# Pelton, Robert                   216       16080     13351716
# Hodges, Robert                    54       11985     13100000
# Lucotte, Marc                    285       10015     12641969
# Woods, Donald                     77       13993     12604187
# Sekaly, RafickPierre             504       16020     12224490
# Rizkalla, Sami                    95        9985     12151000
# Harasim, LindaMarie               35       13986     12034000
# Hewson, William                27728        2007     11985000
# Munkittrick, Kelly                99        6036     11610000
# Fyles, James                      45       10030     11600000
# Sénéchal, David                  408       12057     11358311
# Svensson, Carl                   192       16069     11275000
# Resendes, Rui                  87777        6030     11009195
# Driedzic, William                356        8002     10800000
# Killeen, Ron                   22989        2007     10500000
# Gardner, Philip                27708        2007     10500000
# Maibaum, Thomas                  135       10060     10235000
# Tuer, Kevin                    87672        6030      9786236
# Valliant, John                 83169        6032      9660000
# ElSheimy, Naser                58444        4017      9347000
# Têtu, Michel                     102        3999      9264009
# Withers, Stephen                  36        8010      9262500
# Blostein, Maier                14883        5988      8820000
# Murray, Norman                   248       16084      8800000

# %% [markdown]
# ## Individual Principal Investigator

# %%
nsercDF.loc[nsercDF['Name'].isin(['Gupta, Arvind'])]['AwardAmount'].plot(kind='bar')
